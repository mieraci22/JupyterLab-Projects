# %%
# !pip install matplotlib numpy pandas

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
print("Hello, World!")
# Out:
# Hello, World!

# %%
x = np.linspace(0, 10, 100)
y = np.sin(x)

plt.plot(x, y)
plt.title("Sine Wave")
plt.show()
